# %% [markdown]
# Prompt Chaining : when multiple lllms are called

# %%
from langgraph.graph import StateGraph , START , END
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGoogleGenerativeAI(model='gemini-3.5-flash')

# %%
class BlogState(TypedDict):

    title: str 
    outline: str
    content: str

# %%
def create_outline(state:BlogState)-> BlogState:


    title = state['title']
    prompt=f'Generate a detailed outline for a blog on the topic -{title}'

    outline = model.invoke(prompt).content
    state['outline'] = outline
    return state

# %%
def create_blog(state:BlogState)-> BlogState:
    title = state['title']
    outline = state['outline']

    prompt = f'Write the detailed blog on the title using the following outline \n{outline}'

    content=model.invoke(prompt).content
    state['content'] = content
    return state

# %%
graph = StateGraph(BlogState)

graph.add_node('create_outline' , create_outline )
graph.add_node('create_blog' , create_blog )

graph.add_edge(START ,'create_outline' )
graph.add_edge('create_outline' , 'create_blog')
graph.add_edge( 'create_blog', END)

workflow= graph.compile()

# %%
initial_state = {'title':'Rise of AI in INDIA'}
final_state = workflow.invoke(initial_state)

print(final_state)
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# {'title': 'Rise of AI in INDIA', 'outline': [{'type': 'text', 'text': 'Here is a comprehensive, SEO-optimized blog outline on the **"Rise of AI in India."** This outline is structured to guide a writer through creating a 1,500 to 2,500-word deep-dive article.\n\n---\n\n# Blog Outline: The Rise of AI in India: From IT Hub to Global AI Powerhouse\n\n## **Catchy Title Ideas**\n*   *The Silicon Monsoon: How AI is Redefining India’s Tech Landscape*\n*   *Beyond IT Support: How India is Becoming the AI Capital of the Global South*\n*   *The Rise of AI in India: Opportunities, Innovations, and the Road Ahead*\n*   *From Code to Intelligence: India’s Massive Leap into the AI Era*\n\n---\n\n## **1. Introduction**\n*   **The Hook:** Start with a striking contrast—how India transitioned from being the world’s "back-office/IT helpdesk" in the 1990s and 2000s to a leading creator of cutting-edge AI today.\n*   **The Current Context:** Mention India’s massive digital footprint (fueled by UPI, cheap data, and smartphone penetration).\n*   **The Big Picture (Thesis Statement):** Artificial Intelligence is no longer just a buzzword in India; it is a catalyst driving socio-economic growth, governance, and industrial revolution across the nation.\n*   **Key Statistic/Data Point:** Mention projected market size (e.g., AI\'s potential to add $450–$500 billion to India’s GDP by 2025).\n\n---\n\n## **2. The Catalysts: Why India is Primed for the AI Revolution**\n*   **The "IndiaAI" Mission & Government Support:**\n    *   The Indian Government’s cabinet approval of the ₹10,372 crore ($1.25B) **IndiaAI Mission**.\n    *   NITI Aayog’s "National Strategy for Artificial Intelligence" (#AIforAll).\n    *   Building sovereign AI infrastructure (GPU clusters, AIRAWAT supercomputer).\n*   **The Democratic Advantage (Data & Demographics):**\n    *   Over 800 million active internet users generating massive, diverse datasets.\n    *   The world’s youngest workforce with a massive pool of STEM graduates.\n*   **The Digital Public Infrastructure (DPI) foundation:**\n    *   How India Stack (Aadhaar, UPI, ONDC) provides the perfect digital highway for AI deployment.\n\n---\n\n## **3. Key Sectors Being Transformed by AI in India**\n*   **A. Agriculture (AgriTech):**\n    *   AI-driven crop yield prediction, pest detection, and soil health analysis (e.g., Microsoft’s collaboration with local farmers).\n    *   Precision farming overcoming climate change challenges.\n*   **B. Healthcare:**\n    *   AI diagnostics bridging the rural-urban healthcare divide (e.g., Niramai’s breast cancer screening, AI for tuberculosis detection).\n    *   Predictive analysis for epidemic outbreaks.\n*   **C. Education (EdTech) & Language Democratization:**\n    *   AI-powered personalized learning.\n    *   **Project Bhashini:** AI translation tool breaking language barriers, allowing citizens to access government services in 22 regional languages.\n*   **D. Fintech and E-Commerce:**\n    *   AI-powered credit scoring for the unbanked population.\n    *   Hyper-personalized shopping experiences and vernacular voice search (e.g., Flipkart, Meesho).\n\n---\n\n## **4. The Indian AI Startup & Corporate Ecosystem**\n*   **The Rise of Indic LLMs (Large Language Models):**\n    *   Mention local innovations like Ola’s **Krutrim**, **Sarvam AI** (OpenHathi), and Tech Mahindra’s **Project Indus**.\n    *   Why India needs local models (nuances of Indian culture, multilingual context, cost efficiency).\n*   **SaaS and Enterprise AI:**\n    *   How Indian SaaS giants (Zoho, Freshworks) are embedding generative AI into their products.\n*   **Global MNCs Leveraging Indian Talent:**\n    *   Global GCCs (Global Capability Centers) in Bengaluru, Hyderabad, and Pune pivoting from maintenance to core AI research.\n\n---\n\n## **5. Key Challenges Facing India’s AI Ambitions**\n*   **The Compute/Hardware Bottleneck:**\n    *   Dependence on importing GPUs (NVIDIA chips); lack of domestic semiconductor ...

# %%
print(final_state['outline'])
# Out:
# [{'type': 'text', 'text': 'Here is a comprehensive, SEO-optimized blog outline on the **"Rise of AI in India."** This outline is structured to guide a writer through creating a 1,500 to 2,500-word deep-dive article.\n\n---\n\n# Blog Outline: The Rise of AI in India: From IT Hub to Global AI Powerhouse\n\n## **Catchy Title Ideas**\n*   *The Silicon Monsoon: How AI is Redefining India’s Tech Landscape*\n*   *Beyond IT Support: How India is Becoming the AI Capital of the Global South*\n*   *The Rise of AI in India: Opportunities, Innovations, and the Road Ahead*\n*   *From Code to Intelligence: India’s Massive Leap into the AI Era*\n\n---\n\n## **1. Introduction**\n*   **The Hook:** Start with a striking contrast—how India transitioned from being the world’s "back-office/IT helpdesk" in the 1990s and 2000s to a leading creator of cutting-edge AI today.\n*   **The Current Context:** Mention India’s massive digital footprint (fueled by UPI, cheap data, and smartphone penetration).\n*   **The Big Picture (Thesis Statement):** Artificial Intelligence is no longer just a buzzword in India; it is a catalyst driving socio-economic growth, governance, and industrial revolution across the nation.\n*   **Key Statistic/Data Point:** Mention projected market size (e.g., AI\'s potential to add $450–$500 billion to India’s GDP by 2025).\n\n---\n\n## **2. The Catalysts: Why India is Primed for the AI Revolution**\n*   **The "IndiaAI" Mission & Government Support:**\n    *   The Indian Government’s cabinet approval of the ₹10,372 crore ($1.25B) **IndiaAI Mission**.\n    *   NITI Aayog’s "National Strategy for Artificial Intelligence" (#AIforAll).\n    *   Building sovereign AI infrastructure (GPU clusters, AIRAWAT supercomputer).\n*   **The Democratic Advantage (Data & Demographics):**\n    *   Over 800 million active internet users generating massive, diverse datasets.\n    *   The world’s youngest workforce with a massive pool of STEM graduates.\n*   **The Digital Public Infrastructure (DPI) foundation:**\n    *   How India Stack (Aadhaar, UPI, ONDC) provides the perfect digital highway for AI deployment.\n\n---\n\n## **3. Key Sectors Being Transformed by AI in India**\n*   **A. Agriculture (AgriTech):**\n    *   AI-driven crop yield prediction, pest detection, and soil health analysis (e.g., Microsoft’s collaboration with local farmers).\n    *   Precision farming overcoming climate change challenges.\n*   **B. Healthcare:**\n    *   AI diagnostics bridging the rural-urban healthcare divide (e.g., Niramai’s breast cancer screening, AI for tuberculosis detection).\n    *   Predictive analysis for epidemic outbreaks.\n*   **C. Education (EdTech) & Language Democratization:**\n    *   AI-powered personalized learning.\n    *   **Project Bhashini:** AI translation tool breaking language barriers, allowing citizens to access government services in 22 regional languages.\n*   **D. Fintech and E-Commerce:**\n    *   AI-powered credit scoring for the unbanked population.\n    *   Hyper-personalized shopping experiences and vernacular voice search (e.g., Flipkart, Meesho).\n\n---\n\n## **4. The Indian AI Startup & Corporate Ecosystem**\n*   **The Rise of Indic LLMs (Large Language Models):**\n    *   Mention local innovations like Ola’s **Krutrim**, **Sarvam AI** (OpenHathi), and Tech Mahindra’s **Project Indus**.\n    *   Why India needs local models (nuances of Indian culture, multilingual context, cost efficiency).\n*   **SaaS and Enterprise AI:**\n    *   How Indian SaaS giants (Zoho, Freshworks) are embedding generative AI into their products.\n*   **Global MNCs Leveraging Indian Talent:**\n    *   Global GCCs (Global Capability Centers) in Bengaluru, Hyderabad, and Pune pivoting from maintenance to core AI research.\n\n---\n\n## **5. Key Challenges Facing India’s AI Ambitions**\n*   **The Compute/Hardware Bottleneck:**\n    *   Dependence on importing GPUs (NVIDIA chips); lack of domestic semiconductor fabrication.\n*   **The Skill and Research  ...
